# %% [markdown]
# <a href="https://colab.research.google.com/github/pyaswanth/AITTA/blob/main/sine_cos_wave.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,20,100)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.show()
